# %% [markdown]
# # Wafer Classification
#
# This is a lightweight notebook handoff for the web-app repository.
#
# Original full Colab notebook: https://github.com/josephfkung-del/DementiaBank-Classifcation/blob/main/Wafer_Classification.ipynb
#
# The full notebook includes embedded outputs and training logs. For deployment, export the trained Keras model from Colab with:
#
# ```python
# model.save('wafer_classifier.keras')
# ```
#
# Then place the file at `model/wafer_classifier.keras` in this repository or upload it to the deployment platform as a model artifact.

# %%
# Deployment export step to run at the end of the training notebook
# model.save('wafer_classifier.keras')
